# %% [markdown]
# # Wrangle OpenStreetMap Data

# %% [markdown]
# # Project Overview
#
# From https://www.openstreetmap.org I choose my hometown of Detroit, MI.
#
# Goals:
#
# - Assess the quality of the data for validity, accuracy, completeness, consistency and uniformity.
# - Parse and gather data from popular file formats such as .csv, .json, .xml, and .html
# - Process data from multiple files or very large files that can be cleaned programmatically.
# - Store, query, and aggregate data using SQL.

# %% [markdown]
# First I looked at XML elements (nodes,way points, relation) information I found here: https://wiki.openstreetmap.org/wiki/OSM_XML

# %% [markdown]
# # Node
# Nodes are individual dots used to mark specific locations. See example below:

# %% [markdown]
# # Way point
# Ways are used to create roads, paths, rivers, etc. See example below:

# %% [markdown]
# # Relation
# Relations are used to create map features, such as cycling routes, turn restrictions and areas that are not contiguous. See example below:

# %% [markdown]
# Looking through my OSM File I see some outstanding issues
# # Problems:

# %% [raw]
# Case sensitiveness:
#
#     street: Street
#     road : Road
#     lake: Lake
#     alley : Alley
#
# Abbreviations inconsitancy:
#
#     St: Street
#     Rd : Road
#     Dr : Drive
#     Hwy : Highway
#     Ct : Court
#     Ln : Lane
#     Ave : Avenue
#     Cir : Circle
#     Pl : Place
#     Mt : Mountain
#     Sq : Square
#     Ter: Terrace
#     N: North
#     E : East

# %% [markdown]
# # Goal #1
#
# - Assess the quality of the data for validity, accuracy, completeness, consistency and uniformity.
#
# **Data Exploration**

# %%
import os
os.getcwd()
# Out:
# 'C:\\Wrangle OpenStreetMap Data'

# %%
os.chdir("C:\Wrangle OpenStreetMap Data")
os.getcwd()
# Out:
# 'C:\\Wrangle OpenStreetMap Data'

# %%
#Importing modules
import xml.etree.ElementTree as ET
from collections import defaultdict
import re
import pprint
import csv
import codecs

# %% [markdown]
# **Get SAMPLE FILE**

# %%
#Import osm file and create sample dataset

#!/usr/bin/env python
# -*- coding: utf-8 -*-

OSM_FILE = "detroit_map.osm"
OSMFILE = "sample.osm"

k = 10 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

            
with open(OSMFILE, 'w', encoding='utf8') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')
    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='unicode'))
    output.write('</osm>')

# %% [markdown]
# **Count the unique element types.**

# %%
def count_tags(filename):
    tags = {}
    for event, elem in ET.iterparse(filename, events=('start', )):
        if elem.tag not in tags:
            tags[elem.tag] = 1
        else:
            tags[elem.tag] += 1
    return tags

def test():

    tags = count_tags('sample.osm')
    pprint.pprint(tags)
    

if __name__ == "__main__":
    test()
# Out:
# {'member': 18040,
#  'nd': 448870,
#  'node': 364200,
#  'osm': 1,
#  'relation': 810,
#  'tag': 173071,
#  'way': 63842}

# %% [markdown]
# **Getting the "k" value and  a count** of each of the tag categories in a dictionary.

# %%
lower = re.compile(r'^([0-9a-z]|_)*$') #valid tags that contain only lowercase letters 
lower_colon = re.compile(r'^([a-z]|_)*:([0-9a-z]|_|-)*$') #valid lowercase letter tags with a colon in their names
upper = re.compile(r'^([A-Z]|_)*$') #valid tags that contain only uppercase letters
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]') #tags with problematic characters


def key_type(element, keys):
    if element.tag == "tag":
        if lower.search(element.attrib['k']):
            keys['lower'] += 1
            # print('lower: ' + element.attrib['k'])
        elif lower_colon.search(element.attrib['k']):
            keys['lower_colon'] += 1
            # print('lower_col: ' + element.attrib['k'])
        elif upper.search(element.attrib['k']):
            keys['upper'] += 1
            # print('upper: ' + element.attrib['k'])
        elif problemchars.search(element.attrib['k']):
            keys['problemchars'] += 1
            # print('prob: ' + element.attrib['k'])
        else:
            # print('other--  ' + element.attrib['k'])
            keys['other'] += 1
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "upper":0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys


if __name__ == "__main__":
    pm = process_map('sample.osm')
    pprint.pprint(pm)
# Out:
# {'lower': 122403,
#  'lower_colon': 48495,
#  'other': 2020,
#  'problemchars': 0,
#  'upper': 153}

# %% [markdown]
# **Unique Users**

# %%
def get_user(element):
    return


def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        try:
            users.add(element.attrib['uid'])
        except KeyError:
            continue

    return users


def test():

    users = process_map('sample.osm')
    pprint.pprint(len(users))

if __name__ == "__main__":
    test()
# Out:
# 1550

# %% [markdown]
# **Checking the validity and consistency**
#
# Lets take a look at the street names and do some cleaning

# %%
OSMFILE = "sample.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Road", "Street", "Drive", "Highway", "Lane", "Avenue","Boulevard", "Circle", "Court", "Crescent", "Grove",
             "Place"]

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def print_sorted_dic(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print("%s: %d" % (k, v))

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit():
#    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(OSMFILE, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    pprint.pprint(dict(street_types))

if __name__ == '__main__':
    audit()
# Out:
# {'10': {'Concession Road 10', 'Sideroad 9 & 10'},
#  '11': {'Concession Road 11'},
#  '12': {'Concession Road 12'},
#  '14': {'Sideroad 13 & 14'},
#  '17': {'Sideroad 16 & 17'},
#  '22': {'County Road 22'},
#  '3': {'Concession Road 3', 'Kings Highway 3'},
#  '34': {'County Road 34'},
#  '4': {'Concession Road 4'},
#  '42': {'County Road 42'},
#  '46': {'County Road 46'},
#  '6': {'Concession Road 6'},
#  '7': {'Concession Road 7'},
#  '8': {'Concession Road 8'},
#  '9': {'Concession Road 9'},
#  'Affeldt': {'Affeldt'},
#  'Ave': {'Gratiot Ave', 'Michigan Ave', 'Grand River Ave'},
#  'Ave.': {'Jefferson Ave.'},
#  'Belmont': {'Belmont'},
#  'Blvd': {'Lacasse Blvd', 'East Boston Blvd', 'West Boston Blvd'},
#  'Blvd.': {'Little River Blvd.'},
#  'Canterbury': {'Canterbury'},
#  'Cove': {'Glen Cove'},
#  'Dequindre': {'Dequindre'},
#  'Detroit': {'Mt Elliott St, Detroit'},
#  'Dr.': {'Westchester Dr.'},
#  'East': {'Cabana Road East',
#           'Chatham Street East',
#           'Grand Marais Road East',
#           'Kennedy Drive East',
#           'Lantz Street East',
#           'North Service Road East',
#           'Riverside Drive East',
#           'Roseland Drive East',
#           'Rvierside Drive East',
#           'Tecumseh Road East',
#           'Wyandotte Street East'},
#  'Edwin': {'Edwin'},
#  'Evaline': {'Evaline'},
#  'Fair': {'West State Fair'},
#  'Freeway': {'Edsel Ford Freeway',
#              'James Couzens Freeway',
#              'Southfield Freeway'},
#  'Leathorne': {'Leathorne'},
#  'Lenox': {'Lenox'},
#  'Lichfield': {'Lichfield'},
#  'Livernois': {'Livernois'},
#  'McNichols': {'W McNichols', 'West McNichols'},
#  'Mile': {'Little Mack / 11 Mile'},
#  'Monica': {'Monica'},
#  'Norborne': {'Norborne'},
#  'North': {'Wilder Drive North'},
#  'Park': {'Estate Park', 'Dorset Park'},
#  'Parkway': {'Lauzon Parkway'},
#  'Picadilly': {'Picadilly'},
#  'Prairie': {'Prairie'},
#  'Rd': {'E 11 Mile Rd',
#         'E 9 Mile Rd',
#         'E McNichols Rd',
#         'Evergreen Rd',
#         'Plymouth Rd'},
#  'Rd.': {'W. 7 Mile Rd.'},
#  'Rosa': {'Santa Rosa'},
#  'Rose': {'St. Rose'},
#  'Shrewsbury': {'Shrewsbury'},
#  'Sideroad': {'Sexton Sideroad'},
#  'South': {'Roseland Drive South',
#            'Villa Maria Boulevard South',
#            'Wilder Drive South'},
#  'Square': {'Cadillac Square'},
#  'St': {'West Congress St'},
#  'St.': {'Rockwood St.'},
#  'Stoepel': {'Stoepel'},
#  'Straford': {'Straford'},
#  'Stratford': {'Stratford'},
#  'Trail': {'Ann Arbor Trail'},
#  'Vernor': {'E Vernor'},
#  'Washington': {'Washington'},
#  'Way': {'George Kennedy Way',
#          'Grantham Way',
#          'Jessica Way',
#          'Kings Gate Way',
#          'Mannheim Way',
#          'Walstedt Way'},
#  'West': {'Adams Street West',
#           'Bethune Street West',
#           'Davison Street West',
#           'Fort Street West',
#           'Front Road West',
#           'Jefferson Avenue West',
#           'Tecumseh Road West'},
#  'Wynd': {'Shorehaven Wynd'},
#  'Yemans': {'Yemans'}}

# %%
OSMFILE = "sample.osm"

mapping = {    "Rd" : "Road",
               "Rd." : "Road",
               "road" : "Road",
               #"St": "Street",
               "street": "Street",
               "Dr." : "Drive",
               "Hwy" : "Highway",
               "Ln" : "Lane",
               "Ave" : "Avenue",
               #"Mt" : "Mount",
               #"Mt" : "Mountain",
               #"N" : "North",
               #"E" : "East",
               #"W" : "West",
               "Blvd" : "Boulevard",
               "Blvd." : "Boulevard"
            }

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osmfile, events=("start",)):

        if elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types


def update_name(name, mapping):
    for key, value in mapping.items():
        if re.search(key, name):
            name = re.sub(street_type_re, value, name)

    return name


def test():
    st_types = audit(OSMFILE)
    for st_type, ways in st_types.items():
        for name in ways:
            better_name = update_name(name, mapping)
            print (name, "=>", better_name)


if __name__ == '__main__':
    test()
# Out:
# Evergreen Rd => Evergreen Road
# E 11 Mile Rd => E 11 Mile Road
# Plymouth Rd => Plymouth Road
# Mt Elliott St, Detroit => Mt Elliott St, Detroit
# W McNichols => W McNichols
# West McNichols => West McNichols
# West State Fair => West State Fair
# Davison Street West => Davison Street West
# Bethune Street West => Bethune Street West
# Adams Street West => Adams Street West
# Tecumseh Road West => Tecumseh Road West
# Jefferson Avenue West => Jefferson Avenue Avenue
# Fort Street West => Fort Street West
# Cadillac Square => Cadillac Square
# West Congress St => West Congress St
# Jefferson Ave. => Jefferson Avenue
# Westchester Dr. => Westchester Drive
# St. Rose => St. Rose
# Little River Blvd. => Little River Boulevard
# Tecumseh Road East => Tecumseh Road East
# Rvierside Drive East => Rvierside Drive Drive
# Grand Marais Road East => Grand Marais Road East
# Wyandotte Street East => Wyandotte Street East
# Lantz Street East => Lantz Street East
# Riverside Drive East => Riverside Drive Drive
# Chatham Street East => Chatham Street East
# Ann Arbor Trail => Ann Arbor Trail
# Lichfield => Lichfield
# Belmont => Belmont
# Yemans => Yemans
# Dequindre => Dequindre
# Edwin => Edwin
# Evaline => Evaline
# Lenox => Lenox
# Stratford => Stratford
# Straford => Straford
# Picadilly => Picadilly
# Canterbury => Canterbury
# Livernois => Livernois
# Stoepel => Stoepel
# Santa Rosa => Santa Rosa
# Monica => Monica
# Prairie => Prairie
# Shrewsbury => Shrewsbury
# Lacasse Blvd => Lacasse Boulevard
# East Boston Blvd => East Boston Boulevard
# West Boston Blvd => West Boston Boulevard
# Kings Gate Way => Kings Gate Way
# Glen Cove => Glen Cove
# Edsel Ford Freeway => Edsel Ford Freeway
# James Couzens Freeway => James Couzens Freeway
# Little Mack / 11 Mile => Little Mack / 11 Mile
# Michigan Ave => Michigan Avenue
# Affeldt => Affeldt
# Norborne => Norborne

# %% [markdown]
# No problems here

# %% [markdown]
# **Checking zip codes**

# %%
# Here we create a dictionary of our postal codes
def audit_postal_code(postal_code_types, postal_code):  
    if not postal_code.isupper() or ' ' not in postal_code:
        postal_code_types['Postal Codes'].add(postal_code)
    else:
        postal_code_types['other'].add(postal_code)
    return postal_code_types

def is_postal_code(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit(filename):
    f = (filename)
    postal_code_types = defaultdict(set)
    
    for event, element in ET.iterparse(f, events=("start",)):
        if element.tag =="way":
            for tag in element.iter("tag"):
                if is_postal_code(tag):
                    audit_postal_code(postal_code_types, tag.attrib['v'])
    print(dict(postal_code_types))

if __name__ == '__main__':
    audit(OSMFILE)
# Out:
# {'other': {'N9A 1X9', 'N8Y 1L4', 'N9A 1T1', 'N9A 4N2', 'N8N 3P3', 'N9J 2A5', 'N8N 2C1', 'N9G 3G1', 'N8N 1A6', 'N9G 3E6', 'N9G 3G5', 'N8N 1A7', 'N9G 3E5', 'N8S 1X4', 'N9C 2J9', 'N8S 1E6', 'N8S 1B6', 'N8T 1C5', 'N8Y 1R7', 'N8P 1L7', 'N9A 4N1', 'N9C 4G8', 'N9A 2X2', 'N8S 4V2', 'N8N 1A8', 'N9B 3P4', 'N9C 1C3', 'N9B 0B9', 'N8X 2T2', 'N8X 1P1', 'N8X 4K2', 'N9A 6Z3', 'N8S 1N3', 'N8P 2A3', 'N9A 3B3', 'N8P 1A1', 'N9A 5A4', 'N9B 2Z8', 'N8N 1A4', 'N9A 1H6', 'N9A 5S8', 'N8R 1E9', 'N9B 0B6', 'N8T 1S1', 'N9G 1V9', 'N8X 1H4', 'N8S 3N1', 'N9A 6N5', 'N9A 1S8', 'N8W 1Y6', 'N8N 1A9', 'N9G 3E7', 'N8N 1A3', 'N8T 2H9', 'N8S 1W4'}, 'Postal Codes': {'48184', '48238', '48221', '48214', '48236', '48230', '2651', '48124', '48015', '48220', '48076', '48066', '48205', '48071', '48206', '48235-2356', '48334', '48209', '48375', '48229', '48030', '48075', '48067', '48335', '48237', '48234', '48091', '48152', '48126', '48185', '48239', '48201', '48200', '48212', '48167', '48213', '48150', '48215', '48226', '48217', '48127', '48141', '48240', '48204', '48207', '48216', '48180', '48086', '48219', '48034', '48195', '48192', '48224', '48233-9998', '48223', '48203', '48228', '48235', '48090', '48174', '48089', '48377', '48070', '48146', '48211', '48101', '48122', '48210', '48227', '48120', '48072', '48208', '48336', '48168', '48125', '48021', '48202'}}

# %%
OSMFILE = "sample.osm"
postal_code_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["48184", "48238", "48221", "48214", "48236", "48230", "2651", "48124",
            "48015", "48220", "48076", "48066", "48205", "48071", "48206", "48235-2356", 
            "48334", "48209", "48375", "48229", "48030", "48075", "48067", "48335", "48237",
            "48234", "48091", "48152", "48126", "48185", "48239", "48201", "48200", "48212",
            "48167", "48213", "48150", "48215", "48226", "48217", "48127", "48141", "48240",
            "48204", "48207", "48216", "48180", "48086", "48219", "48034", "48195", "48192",
            "48224", "48233-9998", "48223", "48203", "48228", "48235", "48090", "48174", "48089",
            "48377", "48070", "48146", "48211", "48101", "48122", "48210", "48227", "48120", "48072",
            "48208", "48336", "48168", "48125", "48021", "48202"]


def audit_postal_code(postal_code_types, postal_codes):
    m = postal_code_type_re.search(postal_codes)
    if m:
        postal_code = m.group()
        if postal_code not in expected:
            postal_code_types[postal_code].add(postal_code)

def is_postal_code(elem):
    return (elem.attrib['k'] == "addr:postcode")


def audit():
    postal_codes = defaultdict(set)
    for event, elem in ET.iterparse(OSMFILE, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_postal_code(tag):
                    audit_postal_code(postal_codes, tag.attrib['v'])
    
    print("Postal codes in data set that are not in Detroit")
    pprint.pprint(dict(postal_codes))

if __name__ == '__main__':
    audit()
# Out:
# Postal codes in data set that are not in Detroit
# {'0B6': {'0B6'},
#  '0B9': {'0B9'},
#  '1A1': {'1A1'},
#  '1A2': {'1A2'},
#  '1A3': {'1A3'},
#  '1A4': {'1A4'},
#  '1A6': {'1A6'},
#  '1A7': {'1A7'},
#  '1A8': {'1A8'},
#  '1A9': {'1A9'},
#  '1B6': {'1B6'},
#  '1C3': {'1C3'},
#  '1C5': {'1C5'},
#  '1E6': {'1E6'},
#  '1E9': {'1E9'},
#  '1H4': {'1H4'},
#  '1H6': {'1H6'},
#  '1L4': {'1L4'},
#  '1L7': {'1L7'},
#  '1N3': {'1N3'},
#  '1P1': {'1P1'},
#  '1R7': {'1R7'},
#  '1S1': {'1S1'},
#  '1S4': {'1S4'},
#  '1S8': {'1S8'},
#  '1T1': {'1T1'},
#  '1V9': {'1V9'},
#  '1W4': {'1W4'},
#  '1X4': {'1X4'},
#  '1X7': {'1X7'},
#  '1X9': {'1X9'},
#  '1Y6': {'1Y6'},
#  '2A3': {'2A3'},
#  '2A5': {'2A5'},
#  '2C1': {'2C1'},
#  '2H9': {'2H9'},
#  '2J9': {'2J9'},
#  '2L9': {'2L9'},
#  '2M1': {'2M1'},
#  '2M9': {'2M9'},
#  '2T2': {'2T2'},
#  '2X2': {'2X2'},
#  '2Z8': {'2Z8'},
#  '3B3': {'3B3'},
#  '3E5': {'3E5'},
#  '3E6': {'3E6'},
#  '3E7': {'3E7'},
#  '3G1': {'3G1'},
#  '3G5': {'3G5'},
#  '3N1': {'3N1'},
#  '3P3': {'3P3'},
#  '3P4': {'3P4'},
#  '3P5': {'3P5'},
#  '3S1': {'3S1'},
#  '48073': {'48073'},
#  '48080': {'48080'},
#  '48081': {'48081'},
#  '48331': {'48331'},
#  '4G8': {'4G8'},
#  '4K2': {'4K2'},
#  '4L2': {'4L2'},
#  '4N1': {'4N1'},
#  '4N2': {'4N2'},
#  '4V2': {'4V2'},
#  '5A4': {'5A4'},
#  '5M5': {'5M5'},
#  '5S8': {'5S8'},
#  '5W8': {'5W8'},
#  '6N5': {'6N5'},
#  '6T3': {'6T3'},
#  '6Z3': {'6Z3'}}

# %% [markdown]
# **Unique Keys**

# %%
def unique_keys(filename):
    distinct_keys=[]
    count=1

    EL=get_element(filename, tags=('node', 'way', 'relation'))
    for element in EL:
        if element.tag=='node' or element.tag=='way':
            for tag in element.iter('tag'):
                if tag.attrib['k'] not in distinct_keys:
                    distinct_keys.append(tag.attrib['k'])
                    count+=1
    distinct_keys.sort()
    print("Total number of unique keys (tag attrib['k'])is {}:".format(count))
    
#    return distinct_keys
    pprint.pprint(distinct_keys)
    
unique_keys(OSMFILE)
# Out:
# Total number of unique keys (tag attrib['k'])is 563:
# ['NHD:ComID',
#  'NHD:FCode',
#  'NHD:FDate',
#  'NHD:FTYPE',
#  'NHD:FType',
#  'NHD:GNIS_ID',
#  'NHD:RESOLUTION',
#  'NHD:ReachCode',
#  'NHD:way_id',
#  'NHS',
#  'abandoned',
#  'abandoned:amenity',
#  'abandoned:building',
#  'access',
#  'addr:city',
#  'addr:city:simc',
#  'addr:country',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:interpolation',
#  'addr:postcode',
#  'addr:province',
#  'addr:state',
#  'addr:street',
#  'addr:unit',
#  'admin_level',
#  'advertising',
#  'aeroway',
#  'alt_name',
#  'amenity',
#  'amenity_1',
#  'animal_keeping',
#  'animal_keeping:type',
#  'architect',
#  'area',
#  'area:highway',
#  'artist_name',
#  'artwork_type',
#  'atm',
#  'attribution',
#  'automatic_door',
#  'backrest',
#  'barrier',
#  'barrier:rfid',
#  'beauty',
#  'beds',
#  'bench',
#  'bicycle',
#  'bicycle_parking',
#  'bin',
#  'board_type',
#  'boat',
#  'bollard',
#  'border_type',
#  'boundary',
#  'brand',
#  'brand:wikidata',
#  'brand:wikipedia',
#  'bridge',
#  'bridge:structure',
#  'bridge:support',
#  'building',
#  'building:colour',
#  'building:flats',
#  'building:levels',
#  'building:levels:underground',
#  'building:material',
#  'building:min_level',
#  'building:part',
#  'building:roof:shape',
#  'building:year_built',
#  'bus',
#  'button_operated',
#  'cables',
#  'camera:mount',
#  'capacity',
#  'capacity:disabled',
#  'census:population',
#  'change:lanes',
#  'change:lanes:backward',
#  'change:lanes:forward',
#  'check_date',
#  'check_date:opening_hours',
#  'circuits',
#  'clothes',
#  'club',
#  'collection_times',
#  'colour',
#  'communication:mobile_phone',
#  'communication:radio',
#  'construction',
#  'contact:webcam',
#  'content',
#  'conveying',
#  'country',
#  'covered',
#  'craft',
#  'created_by',
#  'crop',
#  'crossing',
#  'crossing:activation',
#  'crossing:barrier',
#  'crossing:bell',
#  'crossing:island',
#  'crossing:light',
#  'crossing:saltire',
#  'crossing_ref',
#  'cuisine',
#  'currency:USD',
#  'cutting',
#  'cycleway',
#  'cycleway:both',
#  'cycleway:both:width',
#  'cycleway:left',
#  'cycleway:left:buffer',
#  'cycleway:left:oneway',
#  'cycleway:right',
#  'cycleway:right:buffer',
#  'damaged',
#  'delivery',
#  'demolished:building',
#  'denomination',
#  'denotation',
#  'departures',
#  'departures_board',
#  'depot',
#  'description',
#  'design',
#  'design:year',
#  'designation',
#  'destination',
#  'destination:country',
#  'destination:lanes',
#  'destination:lanes:forward',
#  'destination:ref',
#  'destination:ref:lanes',
#  'destination:ref:lanes:forward',
#  'destination:ref:to',
#  'destination:street',
#  'destination:symbol',
#  'destination:symbol:lanes:forward',
#  'diet:vegan',
#  'diet:vegetarian',
#  'direction',
#  'disabled',
#  'dispensing',
#  'disused',
#  'disused:aeroway',
#  'disused:amenity',
#  'disused:highway',
#  'disused:landuse',
#  'disused:leisure',
#  'disused:railway',
#  'disused:shop',
#  'dog',
#  'door',
#  'drive_in',
#  'drive_through',
#  'ele',
#  'electrified',
#  'elevation',
#  'email',
#  'embankment',
#  'embedded_rails',
#  'embedded_rails:lanes:backward',
#  'embedded_rails:lanes:forward',
#  'emergency',
#  'end_date',
#  'entrance',
#  'facebook',
#  'fax',
#  'fee',
#  'fence_type',
#  'fire:damaged',
#  'fire_hydrant:position',
#  'fire_hydrant:type',
#  'fixme',
#  'flag:type',
#  'foot',
#  'footway',
#  'ford',
#  'former_name',
#  'fuel',
#  'fuel:cng',
#  'garden:type',
#  'gauge',
#  'generator:method',
#  'generator:output:electricity',
#  'generator:source',
#  'generator:type',
#  'give_way',
#  'gnis:Class',
#  'gnis:County',
#  'gnis:County_num',
#  'gnis:ST_alpha',
#  'gnis:ST_num',
#  'gnis:county_id',
#  'gnis:county_name',
#  'gnis:created',
#  'gnis:edited',
#  'gnis:fcode',
#  'gnis:feature_id',
#  'gnis:feature_type',
#  'gnis:ftype',
#  'gnis:id',
#  'gnis:import_uuid',
#  'gnis:reviewed',
#  'gnis:state_id',
#  'golf',
#  'golf_cart',
#  'government',
#  'guidepost',
#  'handicap',
#  'handrail',
#  'healthcare',
#  'healthcare:speciality',
#  'height',
#  'heritage',
#  'hgv',
#  'highway',
#  'historic',
#  'historic:end_date',
#  'historic:leisure',
#  'historic:state_date',
#  'history',
#  'hoops',
#  'horse',
#  'iata',
#  'image',
#  'import_uuid',
#  'incline',
#  'indoor',
#  'industrial',
#  'information',
#  'inscription',
#  'intermittent',
#  'internet_access',
#  'internet_access:fee',
#  'is_in',
#  'is_in:county',
#  'is_in:state',
#  'is_in:state_code',
#  'is_in:town',
#  'isced:level',
#  'junction',
#  'junction:ref',
#  'kerb',
#  'lamp_mount',
#  'lamp_type',
#  'landuse',
#  'lanes',
#  'lanes:backward',
#  'lanes:both_ways',
#  'lanes:forward',
#  'layer',
#  'lcm',
#  'lcn',
#  'leaf_cycle',
#  'leaf_type',
#  'leisure',
#  'level',
#  'light_rail',
#  'limited',
#  'line',
#  'line_attachment',
#  'lit',
#  'location',
#  'location:transition',
#  'lottery',
#  'male',
#  'man_made',
#  'man_made:disused',
#  'manhole',
#  'mapillary',
#  'marker',
#  'material',
#  'maxheight',
#  'maxspeed',
#  'maxspeed:advisory',
#  'maxspeed:backward',
#  'maxspeed:forward',
#  'maxspeed:hgv',
#  'maxspeed:type',
#  'memorial',
#  'memorial_type',
#  'military',
#  'min_height',
#  'minspeed',
#  'motor_vehicle',
#  'motorcar',
#  'museum',
#  'museum_type',
#  'name',
#  'name:en',
#  'name:etymology',
#  'name:etymology:wikidata',
#  'name:fr',
#  'name:ru',
#  'name_1',
#  'name_2',
#  'natural',
#  'network',
#  'network:DDOT',
#  'nhd-shp:com_id',
#  'nhd-shp:fdate',
#  'no_parking:hours',
#  'no_straight_on',
#  'noexit',
#  'noname',
#  'noref',
#  'note',
#  'note:lanes',
#  'note:old_railway_operator',
#  'objects',
#  'office',
#  'official_name',
#  'old_name',
#  'old_name:-2018',
#  'old_railway_operator',
#  'old_ref',
#  'oneway',
#  'only',
#  'open_air',
#  'opening_date',
#  'opening_hours',
#  'opening_hours:covid19',
#  'operator',
#  'operator:phone',
#  'operator:type',
#  'organic',
#  'outdoor_seating',
#  'overtaking',
#  'owner',
#  'ownership',
#  'par',
#  'park_ride',
#  'parking',
#  'parking:condition:left',
#  'parking:condition:left:residents',
#  'parking:lane:both',
#  'parking:lane:left',
#  'parking:lane:right',
#  'parking:no',
#  'parking_space',
#  'passenger_lines',
#  'payment:american_express',
#  'payment:bitcoin',
#  'payment:cash',
#  'payment:cheque',
#  'payment:coins',
#  'payment:credit_cards',
#  'payment:debit_cards',
#  'payment:diners_club',
#  'payment:discover_card',
#  'payment:mastercard',
#  'payment:notes',
#  'payment:visa',
#  'pet',
#  'phone',
#  'place',
#  'placement',
#  'plant',
#  'playground',
#  'pole:type',
#  'population',
#  'population:date',
#  'power',
#  'proposed',
#  'psv',
#  'public_transport',
#  'railway',
#  'railway:position',
#  'railway:position:exact',
#  'railway:preferred_direction',
#  'railway:ref',
#  'railway:traffic_mode',
#  'razed',
#  'recycling_type',
#  'ref',
#  'ref:fra_crossing',
#  'ref:nrhp',
#  'religion',
#  'reporting_marks',
#  'residential',
#  'role',
#  'roof:colour',
#  'roof:height',
#  'roof:levels',
#  'roof:material',
#  'roof:shape',
#  'room',
#  'rooms',
#  'sac_scale',
#  'salt',
#  'school:language',
#  'screen',
#  'seamark:beacon_lateral:category',
#  'seamark:beacon_lateral:colour',
#  'seamark:beacon_lateral:shape',
#  'seamark:beacon_special_purpose:category',
#  'seamark:beacon_special_purpose:shape',
#  'seamark:buoy_cardinal:category',
#  'seamark:buoy_cardinal:colour',
#  'seamark:buoy_cardinal:colour_pattern',
#  'seamark:buoy_cardinal:shape',
#  'seamark:buoy_lateral:category',
#  'seamark:buoy_lateral:colour',
#  'seamark:buoy_lateral:shape',
#  'seamark:harbour:category',
#  'seamark:information',
#  'seamark:light:character',
#  'seamark:light:colour',
#  'seamark:light:exhibition',
#  'seamark:light:height',
#  'seamark:light:information',
#  'seamark:light:period',
#  'seamark:light:range',
#  'seamark:light:status',
#  'seamark:mooring:category',
#  'seamark:mooring:water_level',
#  'seamark:name',
#  'seamark:period_end',
#  'seamark:period_start',
#  'seamark:small_craft_facility:category',
#  'seamark:status',
#  'seamark:topmark:colour',
#  'seamark:topmark:shape',
#  'seamark:type',
#  'seasonal',
#  'seats',
#  'second_hand',
#  'segregated',
#  'self_service',
#  'service',
#  'service:bicycle:diy',
#  'service:bicycle:pump',
#  'service:bicycle:tools',
#  'service:vehicle:lubrication',
#  'service:vehicle:oil',
#  'service:vehicle:oil_change',
#  'service_times',
#  'shelter',
#  'shelter_type',
#  'shop',
#  'shop_1',
#  'short_name',
#  'side',
#  'sides',
#  'sidewalk',
#  'sidewalk:surface',
#  'sign',
#  'smoking',
#  'smoothness',
#  'social_centre:for',
#  'social_facility',
#  'social_facility:for',
#  'source',
#  'source:geometry',
#  'source:name',
#  'source:noname',
#  'source:outline',
#  'source:population',
#  'source:width',
#  'source_ref',
#  'species:wikidata',
#  'species:wikipedia',
#  'sport',
#  'sport_1',
#  'start_date',
#  'station',
#  'stop',
#  'street_lamp',
#  'street_name',
#  'structure',
#  'studio',
#  'substance',
#  'substation',
#  'supervised',
#  'support',
#  'surface',
#  'surveillance',
#  'surveillance:type',
#  'surveillance:zone',
#  'survey:date',
#  'survey_date',
#  'swimming_pool',
#  'switch',
#  'tactile_paving',
#  'takeaway',
#  'temporary:note',
#  'tiger:cfcc',
#  'tiger:county',
#  'tiger:name_base',
#  'tiger:name_base_1',
#  'tiger:name_base_2',
#  'tiger:name_direction_prefix',
#  'tiger:name_direction_prefix_1',
#  'tiger:name_direction_suffix',
#  'tiger:name_type',
#  'tiger:name_type_1',
#  'tiger:name_type_2',
#  'tiger:reviewed',
#  'tiger:separated',
#  'tiger:source',
#  'tiger:tlid',
#  'tiger:upload_uuid',
#  'tiger:zip_left',
#  'tiger:zip_left_1',
#  'tiger:zip_left_2',
#  'tiger:zip_left_3',
#  'tiger:zip_right',
#  'tiger:zip_right_1',
#  'tiger:zip_right_2',
#  'tiger:zip_right_3',
#  'toilets',
#  'toilets:disposal',
#  'toilets:wheelchair',
#  'toll',
#  'tourism',
#  'tower:construction',
#  'tower:type',
#  'tracktype',
#  'traffic_calming',
#  'traffic_sign',
#  'traffic_signals',
#  'traffic_signals:direction',
#  'traffic_signals:sound',
#  'traffic_signals:vibration',
#  'trail_visibility',
#  'train',
#  'tram',
#  'tunnel',
#  'tunnel:name',
#  'turn',
#  'turn:lanes',
#  'turn:lanes:backward',
#  'turn:lanes:both_ways',
#  'turn:lanes:forward',
#  'type',
#  'unsigned',
#  'unsigned_ref',
#  'usage',
#  'utility',
#  'vehicle',
#  'vending',
#  'voltage',
#  'voltage-high',
#  'voltage:primary',
#  'wall',
#  'waste',
#  'water',
#  'water_source',
#  'waterway',
#  'waterway:type',
#  'website',
#  'wetland',
#  'wheelchair',
#  'width',
#  'wikidata',
#  'wikipedia',
#  'year',
#  'year_of_construction']

# %% [markdown]
# **Auditing the street names**

# %%
# run in Python 3

OSMFILE = "sample.osm"

street_type_re = re.compile('pattern, re.VERBOSE')


# I- count occurences for each street type
def count_street_type(street_type_count, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        street_type_count[street_type] +=1
    else:
        street_type_count[street_name] +=1


# II- group streets by type
def group_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        street_types[street_type].add(street_name)
    else:
        street_types[street_name].add(street_name)

# sorts the count of street types in descending order
def sort_values(street_type_count):
    sorted_counts = []
    d_view = [(v,k) for k,v in street_type_count.items()]
    d_view.sort(reverse=True) # natively sort tuples by first element
    for v,k in d_view:
        sorted_counts.append("%s: %d" % (k,v))
    return sorted_counts


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

# perform all of the above audits on the file
def audit(osmfile):
    osm_file = open(osmfile, "r")

    street_type_count = defaultdict(int)
    street_types = defaultdict(set)
    
    for event, elem in ET.iterparse(osmfile, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    count_street_type(street_type_count, tag.attrib['v'])
                    group_street_type(street_types, tag.attrib['v'])
                
    osm_file.close()

    street_type_count = sort_values(street_type_count)

    return street_type_count, street_types


pprint.pprint(audit(OSMFILE))
# Out:
# (['Tecumseh Road East: 30',
#   'Woodward Avenue: 29',
#   'Wyandotte Street East: 27',
#   'Riverside Drive East: 27',
#   'Spring Lane: 23',
#   'Michigan Avenue: 23',
#   'Lakeview Boulevard: 22',
#   'Fort Street: 17',
#   'West 9 Mile Road: 16',
#   'Webb Street: 16',
#   'Lauzon Road: 16',
#   'Burlingame Street: 16',
#   'Walker Road: 15',
#   'Trowbridge Street: 15',
#   'Malden Road: 15',
#   'Gratiot Avenue: 15',
#   'Collingwood Street: 15',
#   'Calvert Street: 15',
#   'North Talbot Road: 14',
#   'Lawrence Street: 14',
#   'Grand River Avenue: 14',
#   'County Road 42: 14',
#   'Southfield Road: 13',
#   'Rvierside Drive East: 13',
#   'Little River Road: 13',
#   'Edwin Street: 13',
#   'East Jefferson Avenue: 13',
#   'Carlisle Street: 13',
#   'Woodstock Drive: 12',
#   'Northline Road: 12',
#   'Lesperance Road: 12',
#   'Lasalle Boulevard: 12',
#   'Kingston Avenue: 12',
#   'Biddle Avenue: 12',
#   'Tecumseh Road: 11',
#   'Talbot Avenue: 11',
#   'Pillette Road: 11',
#   'Manning Road: 11',
#   'Front Road: 11',
#   'College Avenue: 11',
#   'Borgman Avenue: 11',
#   'Yemans Street: 10',
#   'St. Thomas Street: 10',
#   'Norwalk Street: 10',
#   'Helen Street: 10',
#   'Dix-Toledo Highway: 10',
#   'Dillon Drive: 10',
#   'Brighton Road: 10',
#   'Belmont Street: 10',
#   '3rd Street: 10',
#   'Westminster Boulevard: 9',
#   'West 12 Mile Road: 9',
#   'Renfrew Road: 9',
#   'Reaume Road: 9',
#   'Old Tecumseh Road: 9',
#   'Meadowbrook Lane: 9',
#   'Howard Avenue: 9',
#   'Briarcliff Road: 9',
#   'Stratford: 8',
#   'Rossini Boulevard: 8',
#   'Puce Road: 8',
#   'Picadilly: 8',
#   'Patillo Road: 8',
#   'Mount Elliott Street: 8',
#   'Kentucky Avenue: 8',
#   'Huron Church Line Road: 8',
#   'Humber Street: 8',
#   'Hilton Road: 8',
#   'Eureka Road: 8',
#   'Ethel Street: 8',
#   'County Road 22: 8',
#   'Concession Road 8: 8',
#   'Byng Road: 8',
#   'Baseline Road: 8',
#   '6th Concession Road: 8',
#   '2nd Avenue: 8',
#   'Wildwood Drive: 7',
#   'Westcott Road: 7',
#   'West 7 Mile Road: 7',
#   'Turner Road: 7',
#   'St Gregorys Road: 7',
#   'Seminole Street: 7',
#   'Poland Street: 7',
#   'North Rear Road: 7',
#   'Lincoln Drive: 7',
#   'Greenfield Road: 7',
#   'Glynn Court: 7',
#   'Evaline Street: 7',
#   'Cousineau Road: 7',
#   'Concession Road 9: 7',
#   'Alvin Street: 7',
#   'West Outer Drive: 6',
#   'West McNichols Road: 6',
#   'Watson Avenue: 6',
#   'Tourangeau Road: 6',
#   'St Rose Avenue: 6',
#   'Sideroad 16 & 17: 6',
#   'Russell Street: 6',
#   'Rivard Avenue: 6',
#   'Princess Avenue: 6',
#   'Plymouth Road: 6',
#   'Meldrum Road: 6',
#   'Lichfield Road: 6',
#   'Labadie Road: 6',
#   'Kildare Road: 6',
#   'Joseph Campau Street: 6',
#   'John R Street: 6',
#   'Holbrook Street: 6',
#   'Hart Avenue: 6',
#   'Grant Street: 6',
#   'Grandview Street: 6',
#   'Frazho Road: 6',
#   'Ford Avenue: 6',
#   'Elgin Avenue: 6',
#   'Eastburn Street: 6',
#   'Cass Avenue: 6',
#   'Buckingham Drive: 6',
#   'Bringard Drive: 6',
#   'Banwell Road: 6',
#   '8 Mile Road: 6',
#   '10th Street: 6',
#   'Ypres Boulevard: 5',
#   'York Road: 5',
#   'Woodward Boulevard: 5',
#   'Winfield Drive: 5',
#   'Wallace Avenue: 5',
#   'Wabash Street: 5',
#   'Telegraph Road: 5',
#   'Sunderland Road: 5',
#   'South Talbot Road: 5',
#   'Send Street: 5',
#   'Russell Woods Road: 5',
#   'Rosa Parks Boulevard: 5',
#   'Olive Road: 5',
#   'Oak Street: 5',
#   'Nadine Avenue: 5',
#   'Minto Avenue: 5',
#   'Menard Street: 5',
#   'Matchette Road: 5',
#   'Lehner Court: 5',
#   'Leach Street: 5',
#   'Kings Highway 3: 5',
#   'Kercheval Street: 5',
#   'Kathryn Avenue: 5',
#   'Jefferson Boulevard: 5',
#   'Howard Street: 5',
#   'Hickory Road: 5',
#   'Grand Marais Road East: 5',
#   'Globe Street: 5',
#   'George Kennedy Way: 5',
#   'Fairmount Drive: 5',
#   'Electric Street: 5',
#   'East Canfield Street: 5',
#   'County Road 46: 5',
#   'Central Avenue: 5',
#   'Belle Isle View Boulevard: 5',
#   'Arbour Street: 5',
#   'Alexis Road: 5',
#   '4th Street: 5',
#   'West Warren Avenue: 4',
#   'West Bethune Street: 4',
#   'West Alexandrine Street: 4',
#   'Waterman Drive: 4',
#   'Van Born Road: 4',
#   'Ursuline Street: 4',
#   'Trumbull Street: 4',
#   'Trappers Avenue: 4',
#   'Thompson Boulevard: 4',
#   'Stoepel: 4',
#   'Somme Avenue: 4',
#   'Rushwood Crescent: 4',
#   'Rossini Drive: 4',
#   'Reeck Road: 4',
#   'Porter Street: 4',
#   'Peterboro Street: 4',
#   'Ouellette Avenue: 4',
#   'Norman Road: 4',
#   'Mulberry Road: 4',
#   'Morton Drive: 4',
#   'Meridian Street: 4',
#   'Laurier Drive: 4',
#   'Lanoue Street: 4',
#   'Kings Gate Way: 4',
#   'Isabelle Place: 4',
#   'Huntington Road: 4',
#   'Horton Street: 4',
#   'Heritage Drive: 4',
#   'Haig Avenue: 4',
#   'George Avenue: 4',
#   'Gauthier Drive: 4',
#   'Gardendale Street: 4',
#   'Franois Road: 4',
#   'Franklin Street: 4',
#   'Frank Avenue: 4',
#   'Forest Glade Drive: 4',
#   'Ford Boulevard: 4',
#   'Florian Street: 4',
#   'Farmington Road: 4',
#   'Fairview Boulevard: 4',
#   'Ellrose Avenue: 4',
#   'Edwin: 4',
#   'East 11 Mile Road: 4',
#   'Drouillard Road: 4',
#   'Dorset Park: 4',
#   'Division Road: 4',
#   'Dequindre: 4',
#   'Delaware Avenue: 4',
#   'Dale Street: 4',
#   'Cora Greenwood Drive: 4',
#   'Concession Road 6: 4',
#   'Concession Road 10: 4',
#   'Conant Street: 4',
#   'Chene Street: 4',
#   'Caniff Street: 4',
#   'Cadillac Street: 4',
#   'Cadieux Road: 4',
#   'Cabana Road East: 4',
#   'Barcelona Crescent: 4',
#   'Aubin Road: 4',
#   'Arthur Road: 4',
#   'Allen Road: 4',
#   '6th Street: 4',
#   '12 Mile Road: 4',
#   'Yemans: 3',
#   'Wyoming Street: 3',
#   'Woodland Crescent: 3',
#   'Wilder Drive South: 3',
#   'West Willis Street: 3',
#   'West Vernor Highway: 3',
#   'West Milwaukee Street: 3',
#   'West Lafayette Boulevard: 3',
#   'West Jefferson Avenue: 3',
#   'West Eight Mile Road: 3',
#   'West 11 Mile Road: 3',
#   'Villaire Avenue: 3',
#   'Victory Street: 3',
#   'Victoria Avenue: 3',
#   'Vernon Avenue: 3',
#   'Vandernoot Avenue: 3',
#   'University Avenue: 3',
#   'Tower Drive: 3',
#   'Temple Street: 3',
#   'Steven Drive: 3',
#   'State Street: 3',
#   'St Pierre Avenue: 3',
#   'St Louis Avenue: 3',
#   'St Clair Street: 3',
#   'St Alphonse Avenue: 3',
#   'Sprucewood Avenue: 3',
#   'Southwood Lakes Boulevard: 3',
#   'South Middle Road: 3',
#   'Shawnee Road: 3',
#   'Shannon Place: 3',
#   'Seward Street: 3',
#   'Schaefer Road: 3',
#   'Schaefer Highway: 3',
#   'Scarsdale Road: 3',
#   'Santa Rosa: 3',
#   'Roseville Garden Drive: 3',
#   'Roseland Drive East: 3',
#   'Reginald Street: 3',
#   'Prado Place: 3',
#   'Pope Street: 3',
#   'Penrod Street: 3',
#   'Parkview Avenue: 3',
#   'Paris Avenue: 3',
#   'Outer Drive: 3',
#   'Orchard Lake Road: 3',
#   'Normandy Street: 3',
#   'New York Avenue: 3',
#   'Mound Road: 3',
#   'Morand Street: 3',
#   'Monroe Street: 3',
#   'Monica Street: 3',
#   'Monica: 3',
#   'Mitchell Crescent: 3',
#   'Michael Drive: 3',
#   'Mayfair Avenue: 3',
#   'Matthew Brady Boulevard: 3',
#   'Mason Place: 3',
#   'Mack Avenue: 3',
#   'Lyons Avenue: 3',
#   'Lovell Crescent: 3',
#   'Loebach Drive: 3',
#   'Lloyd George Boulevard: 3',
#   'Livernois Street: 3',
#   'Livernois Avenue: 3',
#   'Little Baseline Road: 3',
#   'Lichfield: 3',
#   'Lauzon Parkway: 3',
#   'Larkin Road: 3',
#   'Lakeview Avenue: 3',
#   'Lakepointe Street: 3',
#   'Lake Trail Drive: 3',
#   'Lafferty Avenue: 3',
#   'Kominar Court: 3',
#   'King James Avenue: 3',
#   'Keppen Boulevard: 3',
#   'Kenwood Boulevard: 3',
#   'John R Road: 3',
#   'Jefferson Boulevard Service Road: 3',
#   'Intersection Road: 3',
#   'International Avenue: 3',
#   'Huron Street: 3',
#   'Hubbell Street: 3',
#   'Henry Street: 3',
#   'Hayes Road: 3',
#   'Hanford Avenue: 3',
#   'Hamilton Avenue: 3',
#   'Hallmark Avenue: 3',
#   'Haggerty Road: 3',
#   'Greenpark Boulevard: 3',
#   'Grayfield Street: 3',
#   'Goddard Road: 3',
#   'Glendale Avenue: 3',
#   'Gignac Crescent: 3',
#   'Fortuna Street: 3',
#   'Fort Street West: 3',
#   'Ford Road: 3',
#   'Faust Avenue: 3',
#   'Fairway Crescent: 3',
#   'Fairlane Drive: 3',
#   'Everts Avenue: 3',
#   'Esplanade Drive: 3',
#   'Esdras Place: 3',
#   'Enterprise Court: 3',
#   'Edward Avenue: 3',
#   'Edmore Drive: 3',
#   'Edgemore Avenue: 3',
#   'Edgar Street: 3',
#   'East State Fair Street: 3',
#   'East Pike Creek Road: 3',
#   'East Kirby Street: 3',
#   'East 9 Mile Road: 3',
#   'Disputed Road: 3',
#   'Deacon Street: 3',
#   'Darlington Crescent: 3',
#   'Curtis Street: 3',
#   'Concession Road 7: 3',
#   'Concession Road 3: 3',
#   'Clemenceau Boulevard: 3',
#   'Clairview Avenue: 3',
#   'Cedarview Street: 3',
#   'Cedar Street: 3',
#   'Canterbury: 3',
#   'Cada Crescent: 3',
#   'Brooklyn Avenue: 3',
#   'Bridgeway Boulevard: 3',
#   'Briarbank Drive: 3',
#   'Blackacre Drive: 3',
#   'Bernard Road: 3',
#   'Belleperche Place: 3',
#   'Bassett Street: 3',
#   'Arncliffe Place: 3',
#   '11 Mile Road: 3',
#   'Woodrow Wilson Street: 2',
#   'Woodlawn Avenue: 2',
#   'Windermere Road: 2',
#   'Winder Street: 2',
#   'Wilkins Street: 2',
#   'Wildberry Crescent: 2',
#   'Westchester Dr.: 2',
#   'West Pike Creek Road: 2',
#   'West Hancock Street: 2',
#   'West Grand Boulevard: 2',
#   'West Forest Avenue: 2',
#   'West Euclid Avenue: 2',
#   'West Davison Avenue: 2',
#   'West Canfield Street: 2',
#   'West 10 Mile Road: 2',
#   'Washington Boulevard: 2',
#   'Washington Avenue: 2',
#   'Warwick Street: 2',
#   'Warner Avenue: 2',
#   'Walnut Street: 2',
#   'Wachna Drive: 2',
#   'Virginia Park Street: 2',
#   'Virginia Avenue: 2',
#   'Vermont Street: 2',
#   'Venetian Avenue: 2',
#   'Trenton Road: 2',
#   'Treeline Court: 2',
#   'Tranby Avenue: 2',
#   'Tamarack Street: 2',
#   'Talbot Road: 2',
#   'Suncrest Court: 2',
#   'Strawberry Drive: 2',
#   'Stephens Road: 2',
#   'St Thomas Crescent: 2',
#   'St Paul Avenue: 2',
#   'Southpark Lane: 2',
#   'Southfield Drive: 2',
#   'Southdale Drive: 2',
#   'Snake Lane Road: 2',
#   'Smeeton Drive: 2',
#   'Slater Street: 2',
#   'Simard Crescent: 2',
#   'Silverdale Drive: 2',
#   'Sideroad 13 & 14: 2',
#   'Shorehaven Wynd: 2',
#   'Shinglecreek Court: 2',
#   'Shields Street: 2',
#   'Shery Lane: 2',
#   'Scofield Avenue: 2',
#   'Schoolcraft Street: 2',
#   'Schoolcraft Road: 2',
#   'Schoenherr Street: 2',
#   'Sarah Court: 2',
#   'Sandison Street: 2',
#   'Saint Johns Street: 2',
#   'Saint Antoine Street: 2',
#   'Ruth Road: 2',
#   'Roxanne Drive: 2',
#   'Rose Street: 2',
#   'Rose Avenue: 2',
#   'Roosevelt Avenue: 2',
#   'Rockport Street: 2',
#   'Robert Road: 2',
#   'Riopelle Street: 2',
#   'Ridge Road: 2',
#   'Richmond Street: 2',
#   'Riberdy Road: 2',
#   'Revland Drive: 2',
#   'Reo Avenue: 2',
#   'Regis Avenue: 2',
#   'Reading Street: 2',
#   'Raymond Avenue: 2',
#   'Randolph Street: 2',
#   'Queen Elizabeth Drive: 2',
#   'Provincial Road: 2',
#   'Promenade Avenue: 2',
#   'Progress Avenue: 2',
#   'Princeton Street: 2',
#   'Prentis Street: 2',
#   'Polonia Park Place: 2',
#   'Poisson Street: 2',
#   'Pineview Crescent: 2',
#   'Piedmont Street: 2',
#   'Pentilly Road: 2',
#   'Orleans Street: 2',
#   'Orchard Park Drive: 2',
#   'Omira Street: 2',
#   'Old Front Road: 2',
#   'Olcott Avenue: 2',
#   'Oakman Boulevard: 2',
#   'Oakland Street: 2',
#   'North Woodmont Avenue: 2',
#   'North Service Road East: 2',
#   'Ninth Street: 2',
#   'Mount Vernon Street: 2',
#   'Mount Olive Grove: 2',
#   'Morningstar Avenue: 2',
#   'Moran Avenue: 2',
#   'Monarch Meadows Drive: 2',
#   'Meyers Road: 2',
#   'Metcalfe Street: 2',
#   'Meighen Road: 2',
#   'Mei Lin Crescent: 2',
#   'McGraw Street: 2',
#   'Mayflower Avenue: 2',
#   'Martinique Drive: 2',
#   'Martin Lane: 2',
#   'Marjorie Drive: 2',
#   'Marie Street: 2',
#   'Marentette Avenue: 2',
#   'Maple Leaf Crescent: 2',
#   'Maple Avenue: 2',
#   'Mancini Court: 2',
#   'Maisonneuve Street: 2',
#   'Madison Street: 2',
#   'Luxury Avenue: 2',
#   'Louis Avenue: 2',
#   'Long Boulevard: 2',
#   'Little River Blvd.: 2',
#   'Linwood Street: 2',
#   'Linwood Avenue: 2',
#   'Lincoln Lane: 2',
#   'Lens Avenue: 2',
#   'Lemonwood Crescent: 2',
#   'Lawndale Street: 2',
#   'Lassaline Avenue: 2',
#   'Lappan Avenue: 2',
#   'Lake Shore Road: 2',
#   'Lacasse Boulevard: 2',
#   'Labute Street: 2',
#   'Kew Drive: 2',
#   'Kenwood Crescent: 2',
#   'Kelly Road: 2',
#   'Kamloops Street: 2',
#   'Jessop Street: 2',
#   'Janisse Drive: 2',
#   'Isack Drive: 2',
#   'Irvine Avenue: 2',
#   'Holburn Street: 2',
#   'Henry Ford Centre Drive: 2',
#   'Hendrie Street: 2',
#   'Hendrie Boulevard: 2',
#   'Helsinki Crescent: 2',
#   'Hazel Street: 2',
#   'Havens Drive: 2',
#   'Harrison Boulevard: 2',
#   'Hansen Crescent: 2',
#   'Halsted Road: 2',
#   'Grosse Pointe Boulevard: 2',
#   'Grondin Avenue: 2',
#   'Griswold Street: 2',
#   'Greendale Drive: 2',
#   'Green Valley Drive: 2',
#   'Grantham Way: 2',
#   'Goyeau Street: 2',
#   'Gouin Street: 2',
#   'Golfwood Crescent: 2',
#   'Golfcourse Crescent: 2',
#   'Glidden Avenue: 2',
#   'Gladwin Boulevard: 2',
#   'Garvey Crescent: 2',
#   'Front Road West: 2',
#   'French Road: 2',
#   'Firgrove Drive: 2',
#   'Fenkell Street: 2',
#   'Farnham Avenue: 2',
#   'Evergreen Drive: 2',
#   'Evaline: 2',
#   'Erskine Street: 2',
#   'Erindale Crescent: 2',
#   'Elyria Court: 2',
#   'Elmstead Road: 2',
#   'Elm Street: 2',
#   'Elm Grove Drive: 2',
#   'Eastlawn Avenue: 2',
#   'East Willis Avenue: 2',
#   'East Warren Avenue: 2',
#   'East Outer Drive: 2',
#   'East Ferry Avenue: 2',
#   'East Boston Blvd: 2',
#   'East Bethune Avenue: 2',
#   'East 8 Mile Road: 2',
#   'Eagle Crescent: 2',
#   'Dynasty Street: 2',
#   'Dundee Road: 2',
#   'Dumouchelle Avenue: 2',
#   'Division Street: 2',
#   'Dicocco Court: 2',
#   'Dickerson : 2',
#   'Dexter Avenue: 2',
#   'Dequindre Road: 2',
#   'Deering Avenue: 2',
#   'Dalzelle Street: 2',
#   'Croydon Drive: 2',
#   'Crawford Avenue: 2',
#   'Cranbrook Crescent: 2',
#   'Coronation Avenue: 2',
#   'Cormorant Street: 2',
#   'Copperfield Place: 2',
#   'Conservation Drive: 2',
#   'Concession Road 11: 2',
#   'Community Crescent: 2',
#   'Collingham Drive: 2',
#   'Cobblestone Crescent: 2',
#   'Clover Avenue: 2',
#   'Clovelly Road: 2',
#   'Clophas Drive: 2',
#   'Clarence Drive: 2',
#   'Clapp Street: 2',
#   'Chilver Road: 2',
#   'Chestnut Drive: 2',
#   'Cherry Street: 2',
#   'Cherry Hill Street: 2',
#   'Cherry Hill Road: 2',
#   'Cherokee Street: 2',
#   'Chatham Street East: 2',
#   'Chateau Avenue: 2',
#   'Charlie Brooks Court: 2',
#   'Chandler Road: 2',
#   'Chandler Park Drive: 2',
#   'Cervi Boulevard: 2',
#   'Centennial Drive: 2',
#   'Caribou Crescent: 2',
#   'Calderwood Avenue: 2',
#   'Burt Road: 2',
#   'Burroughs Street: 2',
#   'Burdick Crescent: 2',
#   'Brush Street: 2',
#   'Brouillette Crescent: 2',
#   'Brenda Crescent: 2',
#   'Brainard Street: 2',
#   'Bowman Street: 2',
#   'Bouffard Road: 2',
#   'Bliss Road: 2',
#   'Bernard Street: 2',
#   'Bentcliffe Court: 2',
#   'Bellevue Street: 2',
#   'Bedford Street: 2',
#   'Barton Crescent: 2',
#   'Bartlet Drive: 2',
#   'Ballard Avenue: 2',
#   'Balfour Boulevard: 2',
#   'Aylmer Avenue: 2',
#   'Austen Drive: 2',
#   'Atwater Crescent: 2',
#   'Aspen Lane: 2',
#   'Ashton Avenue: 2',
#   'Arlington Boulevard: 2',
#   'Applewood Avenue: 2',
#   'Apple Lane: 2',
#   'Antoinette Street: 2',
#   'Anthony Wayne Drive: 2',
#   'Anchor Drive: 2',
#   'Amy Croft Drive: 2',
#   'Alderbrook Drive: 2',
#   'Albert Road: 2',
#   'Aire Court: 2',
#   'Affeldt: 2',
#   '7th Street: 2',
#   '17th Street: 2',
#   '15th Street: 2',
#   'piedmont Street: 1',
#   'Zurich Avenue: 1',
#   'Yorkshire Street: 1',
#   'Wyoming Road: 1',
#   'Wyandotte Street: 1',
#   'Woodward Heights Boulevard: 1',
#   'Woodridge Drive: 1',
#   'Woodmont Avenue: 1',
#   'Wolcott Street: 1',
#   'Wisconsin Street: 1',
#   'Winthrop Street: 1',
#   'Wintermute Avenue: 1',
#   'Winslow Road: 1',
#   'Wilson Avenue: 1',
#   'Willow Drive: 1',
#   'Wilder Drive North: 1',
#   'Wick Road: 1',
#   'Whitefish Crescent: 1',
#   'Whiskey Avenue: 1',
#   'Whelpton Street: 1',
#   'Wheelton Drive: 1',
#   'Westview Avenue: 1',
#   'Westmore Street: 1',
#   'Westlake Drive: 1',
#   'West Warren Street: 1',
#   'West State Fair: 1',
#   'West Palmer Avenue: 1',
#   'West McNichols: 1',
#   'West Larned Street: 1',
#   'West Jefferson Service Drive: 1',
#   'West Davison Street: 1',
#   'West Congress Street: 1',
#   'West Congress St: 1',
#   'West Columbia Street: 1',
#   'West Chicago Street: 1',
#   'West Chicago Boulevard: 1',
#   'West Boston Blvd: 1',
#   'West 4th Street: 1',
#   'Wedgewood Court: 1',
#   'Wayne Road: 1',
#   'Waverly Street: 1',
#   'Watson Street: 1',
#   'Waterman Street: 1',
#   'Waterford Avenue: 1',
#   'Washington: 1',
#   'Warren Road: 1',
#   'Walstedt Way: 1',
#   'Wales Court: 1',
#   'Wales Avenue: 1',
#   'Wahneta Avenue: 1',
#   'Wadsworth Street: 1',
#   'W. 7 Mile Rd.: 1',
#   'W McNichols: 1',
#   'Vollans Street: 1',
#   'Visger Street: 1',
#   'Vintage Oaks Drive: 1',
#   'Vinewood Street: 1',
#   'Vine Court: 1',
#   'Vimy Avenue: 1',
#   'Village Grove Drive: 1',
#   'Villa Maria Boulevard South: 1',
#   'Vickery Lane: 1',
#   'Veronica Court: 1',
#   'Verdun Avenue: 1',
#   'Van Dyke Street: 1',
#   'Van Dyke Avenue: 1',
#   'Valtec Court: 1',
#   'Valente Court: 1',
#   'Ulster Street: 1',
#   'Tyler Road: 1',
#   'Tuttle Avenue: 1',
#   'Tumbleweed Crescent: 1',
#   'Tranquility Avenue: 1',
#   'Trailwood Court: 1',
#   'Traditions Drive: 1',
#   'Tireman Street: 1',
#   'Timber Bay Crescent: 1',
#   'Thornberry Crescent: 1',
#   'Terra Court: 1',
#   'Tecumseh Road West: 1',
#   'Tecumseh Road East;Lauzon Road: 1',
#   'Taylor Street: 1',
#   'Taylor Drive: 1',
#   'Tanglewood Court: 1',
#   'Talbot Lane: 1',
#   'Sylvestre Drive: 1',
#   'Sylvano Crescent: 1',
#   'Sycamore Drive: 1',
#   'Superior Street: 1',
#   'Sunset Lane: 1',
#   'Sunset Avenue: 1',
#   'Suncrest Drive: 1',
#   'Sugarwood Crescent: 1',
#   'Suffolk Street: 1',
#   'Stuart Boulevard: 1',
#   'Strong Street: 1',
#   'Stratford Road: 1',
#   'Straford: 1',
#   'Strabane Avenue: 1',
#   'Stout Street: 1',
#   'Stoepel Avenue: 1',
#   'Stockton Street: 1',
#   'Stillmeadow Road: 1',
#   'Stella Court: 1',
#   'Stanton Street: 1',
#   'Staniszewski Street: 1',
#   'Stanford Street: 1',
#   'Stahelin Avenue: 1',
#   'St. Rose: 1',
#   'St. Pierre Avenue: 1',
#   "St. Mary's Gate Street: 1",
#   'St. Anne Boulevard: 1',
#   'St Michaels Drive: 1',
#   'St Marys Boulevard: 1',
#   'St Marks Road: 1',
#   'St Luke Road: 1',
#   'St Jacques Street: 1',
#   'St Etienne Boulevard: 1',
#   'St Denis Street: 1',
#   'St Clair Avenue: 1',
#   'St Anne Street: 1',
#   'St Andrews Drive: 1',
#   'Spruce Street: 1',
#   'Southfield Freeway: 1',
#   'Southdale Court: 1',
#   'South Woodward Avenue: 1',
#   'South Pacific Avenue: 1',
#   'South National Street: 1',
#   'South Military Street: 1',
#   'South Main Street: 1',
#   'South M 39 Service Drive: 1',
#   'South Gratiot Avenue: 1',
#   'South Beech Daly Road: 1',
#   'Souilliere Drive: 1',
#   'Sorge Crescent: 1',
#   'Soloman Street: 1',
#   'Solar Crescent: 1',
#   'Snake Lane: 1',
#   'Smith Street: 1',
#   'Smith Crescent: 1',
#   'Skinner Street: 1',
#   'Silver Creek Industrial Drive: 1',
#   'Sideroad 9 & 10: 1',
#   'Shrewsbury: 1',
#   'Shoreview Circle: 1',
#   'Shorain Grove: 1',
#   'Shiff Drive: 1',
#   'Shiawassee Drive: 1',
#   'Sherwood Street: 1',
#   'Shenandoah Crescent: 1',
#   'Shelley Crescent: 1',
#   'Sheffield Road: 1',
#   'Shakespeare Street: 1',
#   'Shady Springs Crescent: 1',
#   'Shadetree Crescent: 1',
#   'Sexton Sideroad: 1',
#   'Service B Road: 1',
#   'Selden Street: 1',
#   'Scotten Street: 1',
#   'Scotia Road: 1',
#   'Scotia Drive: 1',
#   'Saulino Court: 1',
#   'Sassafras Avenue: 1',
#   'Santo Drive: 1',
#   'Sandwich Street: 1',
#   'Sanders Street: 1',
#   'Salina Avenue: 1',
#   'Sainte Anne Street: 1',
#   'Saint Jean Street: 1',
#   'Saint James Street: 1',
#   'Saint Aubin Street: 1',
#   'Sagebrush Court: 1',
#   'Sacred Heart Drive: 1',
#   'S. West End Street: 1',
#   'S Telegraph Road: 1',
#   'Ryegate Drive: 1',
#   'Ryan Road: 1',
#   'Russell Road: 1',
#   'Ruggaber Drive: 1',
#   'Rostrevor Court: 1',
#   'Rosemont Avenue: 1',
#   'Roseland Drive South: 1',
#   'Rosebriar Road: 1',
#   'Ronald Avenue: 1',
#   'Rodfam Drive: 1',
#   'Rodfam Court: 1',
#   'Rockwood St.: 1',
#   'Rockhaven Drive: 1',
#   'Robinet Road: 1',
#   'Robert Bradby Drive: 1',
#   'Rivervilla Court: 1',
#   'Riverview Avenue: 1',
#   'Riverside Drive: 1',
#   'Riverdale Avenue: 1',
#   'River Avenue: 1',
#   'Richton Street: 1',
#   'Rhodes Drive: 1',
#   'Republic Drive: 1',
#   'Rene Drive: 1',
#   'Rene Avenue: 1',
#   'Rendezvous Drive: 1',
#   'Rendezvous Court: 1',
#   'Regina Street: 1',
#   'Regent Road: 1',
#   'Regency Crescent: 1',
#   'Regal Drive: 1',
#   'Regal Court: 1',
#   'Reedmere Avenue: 1',
#   'Raymo Road: 1',
#   'Radcliff Avenue: 1',
#   'Quincy Street: 1',
#   'Quick Avenue: 1',
#   'Questa Drive: 1',
#   'Puritan Street: 1',
#   'Pulleyblank Street: 1',
#   'Primrose Place: 1',
#   'Prevost Street: 1',
#   'Prevost Avenue: 1',
#   'Pratt Place: 1',
#   'Prairie Street: 1',
#   'Prairie: 1',
#   'Plymouth Rd: 1',
#   'Pleasant Place: 1',
#   'Pioneer Avenue: 1',
#   'Pinecrest Street: 1',
#   'Pierre Avenue: 1',
#   'Pierella Drive: 1',
#   'Picadilly Road: 1',
#   'Pheasant Run Drive: 1',
#   'Periwinkle Crescent: 1',
#   'Pelissier Street: 1',
#   'Pelham Road: 1',
#   'Pearl Street: 1',
#   'Patrick Avenue: 1',
#   'Pat Hayes Avenue: 1',
#   'Parsons Street: 1',
#   'Parkwood Avenue: 1',
#   'Parker Street: 1',
#   'Park Lane Boulevard: 1',
#   'Park Avenue: 1',
#   'Parent Avenue: 1',
#   'Palms Crescent: 1',
#   'Palmer Avenue: 1',
#   'Pallister Street: 1',
#   'Paige Street: 1',
#   'Oxley Avenue: 1',
#   'Outram Avenue: 1',
#   'Ottawa Street: 1',
#   'Osborn Crescent: 1',
#   'Osaka Circle: 1',
#   'Orford Street: 1',
#   'Orchard Grove: 1',
#   'Oliver Avenue: 1',
#   'Old West Avenue: 1',
#   'Odessa Drive: 1',
#   'Oakpark Drive: 1',
#   'Oakland Avenue: 1',
#   'Oakfield Court: 1',
#   'Oak Drive: 1',
#   "O'neil Drive: 1",
#   'Nova Street: 1',
#   'Northway Avenue: 1',
#   'Northlawn Avenue: 1',
#   'North Woodward Avenue: 1',
#   'North Shore Drive: 1',
#   'North Pacific Avenue: 1',
#   'North Main Street: 1',
#   'Norborne: 1',
#   'Newman Boulevard: 1',
#   'Neal Boulevard: 1',
#   'Napoleon Street: 1',
#   'Naples Crescent: 1',
#   'Mulberry Court: 1',
#   'Mt Elliott St, Detroit: 1',
#   'Mount Sinai Crescent: 1',
#   'Moro Drive: 1',
#   'Montgomery Drive: 1',
#   'Monte Vista Street: 1',
#   'Monroe Avenue: 1',
#   'Mohawk Street: 1',
#   'Miranda Court: 1',
#   'Milloy Street: 1',
#   'Miller Road: 1',
#   'Milano Court: 1',
#   'Michigan Ave: 1',
#   'Michael Crescent: 1',
#   'Merriman Road: 1',
#   'Mendota Avenue: 1',
#   'Menard Lane: 1',
#   'Memorial Avenue: 1',
#   'Melville Drive: 1',
#   'Meloche Street: 1',
#   'Medbury Street: 1',
#   'Meadowcrest Boulevard: 1',
#   'McTavish Avenue: 1',
#   'McNorton Street: 1',
#   'McMahon Avenue: 1',
#   'Mayrand Crescent: 1',
#   'Massimo Crescent: 1',
#   'Martin Drive: 1',
#   'Marseilles Street: 1',
#   'Marlo Court: 1',
#   'Markham Road: 1',
#   'Mark Twain Street: 1',
#   'Marion Avenue: 1',
#   'Marina Grove Crescent: 1',
#   'Marentette Drive: 1',
#   'Mannheim Way: 1',
#   'Manitou Crescent: 1',
#   'Maitland Avenue: 1',
#   'Maguire Street: 1',
#   'Madola Avenue: 1',
#   'MacK Court: 1',
#   'Lynn Street: 1',
#   'Lyndon Street: 1',
#   'Lumpkin Street: 1',
#   'Ludlow Avenue: 1',
#   'Lounsborough Street: 1',
#   'Lori Street: 1',
#   'Lonyo Street: 1',
#   'Longfellow Avenue: 1',
#   'Livernois: 1',
#   'Little Mack Avenue: 1',
#   'Little Mack / 11 Mile: 1',
#   'Lionel Drive: 1',
#   'Linsdale Avenue: 1',
#   'Linda Crescent: 1',
#   'Lincoln Road: 1',
#   'Lincoln Avenue: 1',
#   'Lilac Lane: 1',
#   'Liberty Street: 1',
#   'Levan Road: 1',
#   'Lenox: 1',
#   'Lenoir Street: 1',
#   'Lemire Street: 1',
#   'Leffler Drive: 1',
#   'Leathorne Street: 1',
#   'Leathorne: 1',
#   'Lazzy Court: 1',
#   'Lavindale Street: 1',
#   'Laurendeau Avenue: 1',
#   'Laurel Bay Court: 1',
#   'Latina Court: 1',
#   'Larchmont Street: 1',
#   'Lantz Street East: 1',
#   'Langlois Court: 1',
#   'Lamphere Street: 1',
#   'Lake Shore Drive: 1',
#   'Lacasse Blvd: 1',
#   'La Belle Street: 1',
#   'Kinsman Street: 1',
#   'Kings Highway: 1',
#   'King Louis Street: 1',
#   'King Charles Street: 1',
#   'Kerby Road: 1',
#   'Kensington Boulevard: 1',
#   'Kenney Court: 1',
#   'Kennedy Drive East: 1',
#   'Keating Crescent: 1',
#   'Kautex Drive: 1',
#   'Katella Avenue: 1',
#   'Junction Street: 1',
#   'Joy Road: 1',
#   'Joshua Court: 1',
#   'Joinville Avenue: 1',
#   'John C Lodge Drive: 1',
#   'Jewel Street: 1',
#   'Jessica Way: 1',
#   'Jerome Street: 1',
#   'Jennifer Drive: 1',
#   'Jefferson Avenue West: 1',
#   'Jefferson Ave.: 1',
#   'Jasper Place: 1',
#   'Jarvis Avenue: 1',
#   'Janette Avenue: 1',
#   'Jamie Court: 1',
#   'James Couzens Freeway: 1',
#   'Jacob Drive: 1',
#   'Irongate Circle: 1',
#   'Iris Place: 1',
#   'Irene Street: 1',
#   'Intervale Street: 1',
#   'Inkster Road: 1',
#   'Ida Road: 1',
#   'Huron Church Road: 1',
#   'Huntington Avenue: 1',
#   'Horwood Crescent: 1',
#   'Hoover Street: 1',
#   'Homestead Lane: 1',
#   'Homedale Boulevard: 1',
#   'Holmes Street: 1',
#   'Highland Street: 1',
#   'Henry Ruff Road: 1',
#   'Hemlock Road: 1',
#   'Hebert Street: 1',
#   'Heatherglen Crescent: 1',
#   'Healy Street: 1',
#   'Hayes Avenue: 1',
#   'Hawthorne Drive: 1',
#   'Harper Avenue: 1',
#   'Harmony Drive: 1',
#   'Harcourt Street: 1',
#   'Harbourne Crescent: 1',
#   'Hanley Avenue: 1',
#   'Halstead Crescent: 1',
#   'Haig Street: 1',
#   'Guildwood Crescent: 1',
#   'Grove Street: 1',
#   'Gregory Place: 1',
#   'Greendale Avenue: 1',
#   'Gratiot Street: 1',
#   'Gratiot Ave: 1',
#   'Grant Avenue: 1',
#   'Grandmont Avenue: 1',
#   'Grand River Ave: 1',
#   'Grand Boulevard: 1',
#   'Grace Road: 1',
#   'Goldenwood Drive: 1',
#   'Glicka Court: 1',
#   'Glendale Street: 1',
#   'Glen Cove: 1',
#   'Giselle Crescent: 1',
#   'Girardin Street: 1',
#   'Gilbert Avenue: 1',
#   'Gem Avenue: 1',
#   'Gateside Place: 1',
#   'Gary Avenue: 1',
#   'Garfield Avenue: 1',
#   'Garden Court: 1',
#   'G. N. Booth Drive: 1',
#   'Funaro Crescent: 1',
#   'Fuller Crescent: 1',
#   'Freeland Street: 1',
#   'Franklin Road: 1',
#   'Francois Court: 1',
#   'Foxhill Court: 1',
#   'Forest Glade Court: 1',
#   'Fordline Road: 1',
#   'Fontana Avenue: 1',
#   'Florence Street: 1',
#   'Five Mile Road: 1',
#   'Fiesta Court: 1',
#   'Fielding Court: 1',
#   'Fieldcrest Lane: 1',
#   'Festival Avenue: 1',
#   'Ferndale Avenue: 1',
#   'Federal Drive: 1',
#   'Fairview Street: 1',
#   'Fairview Avenue: 1',
#   'Fairlane Crescent: 1',
#   'Faholo Crescent: 1',
#   'Evergreen Rd: 1',
#   'Estate Park: 1',
#   'Essex Avenue: 1',
#   'Empress Street: 1',
#   'Emmons Boulevard: 1',
#   'Elsworth Avenue: 1',
#   'Elmgate Crescent: 1',
#   'Ellis Street: 1',
#   'Eliot Street: 1',
#   'Edsel Ford Freeway: 1',
#   'Edsel Court: 1',
#   'Eden Drive: 1',
#   'Ecorse Road: 1',
#   'Eastcourt Drive: 1',
#   'Eastbourne Avenue: 1',
#   'East Street: 1',
#   'East Palmer Street: 1',
#   'East Nevada Street: 1',
#   'East McNichols Road: 1',
#   'East Lincoln Avenue: 1',
#   'East Hildale Street: 1',
#   'East Harry Avenue: 1',
#   'East Grand Boulevard: 1',
#   'East Forest Avenue: 1',
#   'East Elizabeth Street: 1',
#   'East Alexandrine Street: 1',
#   'East 7 Mile Road: 1',
#   'East 12 Mile Road: 1',
#   'E.C. Row Avenue: 1',
#   'E Vernor: 1',
#   'E McNichols Rd: 1',
#   'E C Row Avenue: 1',
#   'E 9 Mile Rd: 1',
#   'E 11 Mile Rd: 1',
#   'Durocher Drive: 1',
#   'Durham Place: 1',
#   'Ducharme Street: 1',
#   'Dresden Place: 1',
#   'Dove Lane: 1',
#   'Dougall Avenue: 1',
#   'Doranda Court: 1',
#   'Donlon Street: 1',
#   'Donalda Court: 1',
#   'Docherty Drive: 1',
#   'Docherty Court: 1',
#   'Divine Street: 1',
#   'Devonwood Avenue: 1',
#   'Detroit Avenue: 1',
#   'Deslippe Drive: 1',
#   'Dequindre Street: 1',
#   'Denso Drive: 1',
#   'Demarse Court: 1',
#   'Delmar Street: 1',
#   'Delaware Street: 1',
#   'Del Duca Drive: 1',
#   'Dawson Road: 1',
#   'Davison Street West: 1',
#   'Davenport Street: 1',
#   'Danzig Street: 1',
#   'Daneila Crescent: 1',
#   'Dalton Avenue: 1',
#   'Custer Street: 1',
#   'Culver Avenue: 1',
#   'Crowder Street: 1',
#   'Coventry Court: 1',
#   'Courtland Crescent: 1',
#   'County Road 34: 1',
#   'Cottage Place: 1',
#   'Cortina Crescent: 1',
#   'Coronado Drive: 1',
#   'Cornerstone Boulevard: 1',
#   'Corbi Lane: 1',
#   'Cora Street: 1',
#   'Copperfield Court: 1',
#   'Conway Court: 1',
#   'Concession Road 4: 1',
#   'Concession Road 12: 1',
#   'Colson Street: 1',
#   'Colbourne Drive: 1',
#   'Clay Street: 1',
#   'Claxton Court: 1',
#   'Clark Street: 1',
#   'Clarita Street: 1',
#   'Chrysler Drive: 1',
#   'Christina Crescent: 1',
#   'Christina Court: 1',
#   'Chornoby Crescent: 1',
#   'Chicago Boulevard: 1',
#   'Chestnut Street: 1',
#   'Cherry Hill Court: 1',
#   'Chene Court: 1',
#   'Chelsea Drive: 1',
#   'Chaviva Court: 1',
#   'Chatham Place: 1',
#   'Charlotte Street: 1',
#   'Charlevoix Street: 1',
#   'Charlene Lane: 1',
#   'Champaign Road: 1',
#   'Champ Crescent: 1',
#   'Chambers Drive: 1',
#   'Central Street: 1',
#   'Cedarwood Drive: 1',
#   'Castleton Avenue: 1',
#   'Cass Street: 1',
#   'Caruhel Drive: 1',
#   'Carriage Lane: 1',
#   'Carnegie Avenue: 1',
#   'Cardinal Crescent: 1',
#   'Capri Place: 1',
#   'Capri Court: 1',
#   'Cappelletto Road: 1',
#   'Canyon Street: 1',
#   'Cantelon Drive: 1',
#   'Candlewood Drive: 1',
#   'Candlewood Crescent: 1',
#   'Canberra Avenue: 1',
#   'Canada Street: 1',
#   'Cameron Street: 1',
#   'Camden Avenue: 1',
#   'Cambridge Avenue: 1',
#   'Calvary Street: 1',
#   'California Avenue: 1',
#   'Cadillac Square: 1',
#   'Cabot Avenue: 1',
#   'Budapest Court: 1',
#   'Buckingham Avenue: 1',
#   'Buchanan Street: 1',
#   'Brunswick Avenue: 1',
#   'Brothers Court: 1',
#   'Brombach Street: 1',
#   'Broderick Road: 1',
#   'Broadway Street: 1',
#   'Brewster Street: 1',
#   'Bretton Drive: 1',
#   'Braemar Place: 1',
#   'Brace Street: 1',
#   'Boxwood Court: 1',
#   'Bowie Street: 1',
#   'Boulder Crescent: 1',
#   'Borrelli Drive: 1',
#   'Blueberry Court: 1',
#   'Blue Heron Drive: 1',
#   'Blencarn Court: 1',
#   'Blanchard Drive: 1',
#   'Blaine Street: 1',
#   'Blackthorn Drive: 1',
#   'Bishop Street: 1',
#   'Birmingham Avenue: 1',
#   'Binder Crescent: 1',
#   'Beverly Boulevard: 1',
#   'Betts Avenue: 1',
#   'Bethune Street West: 1',
#   'Bertha Avenue: 1',
#   'Berkshire Street: 1',
#   'Belmont: 1',
#   'Beech Street: 1',
#   'Bechard Beach Avenue: 1',
#   'Beaufait Street: 1',
#   'Beatrice Street: 1',
#   'Beach Grove Drive: 1',
#   'Barton Street: 1',
#   'Barry Avenue: 1',
#   'Bagley Street: 1',
#   'Azar Avenue: 1',
#   'Aurora Drive: 1',
#   'Atwater Street: 1',
#   'Assumption Street: 1',
#   'Ashurst Street: 1',
#   'Ashland Drive: 1',
#   'Ascot Court: 1',
#   'Arvilla Street: 1',
#   'Artesian Street: 1',
#   'Arras Avenue: 1',
#   'Armstrong Avenue: 1',
#   'Argus Street: 1',
#   'Argent Street: 1',
#   'Appoline Street: 1',
#   'Antoine Street: 1',
#   'Antaya Street: 1',
#   'Annie Street: 1',
#   'Anne Avenue: 1',
#   'Ann Arbor Trail: 1',
#   'Amiens Avenue: 1',
#   'American Road: 1',
#   'Amalfi Drive: 1',
#   'Alten Drive: 1',
#   'Alpenrose Avenue: 1',
#   'Aloha Drive: 1',
#   'Allyson Avenue: 1',
#   'Alice Street: 1',
#   'Alfred Street: 1',
#   'Alexandrine Street: 1',
#   'Albert Lane: 1',
#   'Airport Road: 1',
#   'Aire Place: 1',
#   'Advance Boulevard: 1',
#   'Adstoll Avenue: 1',
#   'Adelaide Street: 1',
#   'Adams Street West: 1',
#   'Adams Street: 1',
#   'Acorn Court: 1',
#   'Abington Avenue: 1',
#   'Abbott Street: 1',
#   'Abbey Court: 1',
#   '8th Street: 1',
#   '7 Mile Road: 1',
#   '6 Mile Road: 1',
#   '6 Concession Road: 1',
#   '5th Street: 1',
#   '1st Street: 1',
#   '16th Street: 1',
#   '14th Street: 1',
#   '13th Street: 1',
#   '12th Street: 1',
#   '11th Street: 1'],
#  defaultdict(<class 'set'>,
#              {'10th Street': {'10th Street'},
#               '11 Mile Road': {'11 Mile Road'},
#               '11th Street': {'11th Street'},
#               '12 Mile Road': {'12 Mile Road'},
#               '12th Street': {'12th Street'},
#               '13th Street': {'13th Street'},
#               '14th Street': {'14th Street'},
#               '15th Street': {'15th Street'},
#               '16th Street': {'16th Street'},
#               '17th Street': {'17th Street'},
#               '1st Street': {'1st Street'},
#               '2nd Avenue': {'2nd Avenue'},
#               '3rd Street': {'3rd Street'},
#               '4th Street': {'4th Street'},
#               '5th Street': {'5th Street'},
#               '6 Concession Road': {'6 Concession Road'},
#               '6 Mile Road': {'6 Mile Road'},
#               '6th Concession Road': {'6th Concession Road'},
#               '6th Street': {'6th Street'},
#               '7 Mile Road': {'7 Mile Road'},
#               '7th Street': {'7th Street'},
#               '8 Mile Road': {'8 Mile Road'},
#               '8th Street': {'8th Street'},
#               'Abbey Court': {'Abbey Court'},
#               'Abbott Street': {'Abbott Street'},
#               'Abington Avenue': {'Abington Avenue'},
#               'Wyandotte Street East': {'Wyandotte Street East'},
#               'Wyoming Road': {'Wyoming Road'},
#               'Wyoming Street': {'Wyoming Street'},
#               'Yemans': {'Yemans'},
#               'Yemans Street': {'Yemans Street'},
#               'York Road': {'York Road'},
#               'Yorkshire Street': {'Yorkshire Street'},
#               'Ypres Boulevard': {'Ypres Boulevard'},
#               'Zurich Avenue': {'Zurich Avenue'},
#               'piedmont Street': {'piedmont Street'}}))

# %% [markdown]
# Checking on **state names**

# %%
def is_state(elem):
    return (elem.attrib['k'] == "addr:state")

state_types = defaultdict(int)

def audit_state(state_types, state_name):
    if state_name != 'VA':
        state_types[state_name] += 1
        print(state_name)

for event, elem in ET.iterparse(OSMFILE, events =("start",)):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if is_state(tag):
                audit_state(state_types, tag.attrib['v'])
# Out:
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI
# MI

# %% [markdown]
# And lastly **phone numbers**

# %%
def is_phone(elem):
    return (elem.attrib['k'] == "phone" or elem.attrib['k'] == "contact:phone")

def audit_phone_number_formats(phone_number_formats, phone_number):

    # Convert any digit to an 'X' sign (e.g. '(212) 333-3100' becomes '(XXX) XXX-XXXX')
    phone_number_format = re.sub('\d', 'X', phone_number)
    phone_number_formats[phone_number_format] += 1

def audit(osmfile):
    osmfile = OSMFILE
    phone_number_formats = defaultdict(int)
    for event, elem in ET.iterparse(osmfile, events=('start',)):

        if elem.tag == 'node' or elem.tag == 'way':
            for tag in elem.iter('tag'):
                # Audit phone numbers
                if is_phone(tag):
                    audit_phone_number_formats(phone_number_formats, tag.attrib['v'])
    pprint.pprint(dict(phone_number_formats))

audit(OSMFILE)
# Out:
# {'+X XXX XXX XXXX': 17,
#  '+X XXX XXX-XXXX': 4,
#  '+X XXX XXXXXXX': 1,
#  '+X XXX-XXX-XXXX': 3,
#  '+X-XXX-XXX-XXXX': 85,
#  '+XXXXXXXXXXX': 1,
#  'XXX-XXX-XXXX': 1}

# %% [markdown]
# One last cleap up of the dataset

# %%
OSMFILE = "sample.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Road", "Street", "Drive", "Highway", "Lane", "Avenue","Boulevard", "Circle", "Court", "Crescent", "Grove",
             "Place"]

mapping = {    "Rd" : "Road",
               "Rd." : "Road",
               "road" : "Road",
               #"St": "Street",
               "street": "Street",
               "Dr." : "Drive",
               "Hwy" : "Highway",
               "Ln" : "Lane",
               "Ave" : "Avenue",
               #"Mt" : "Mount",
               #"Mt" : "Mountain",
               #"N" : "North",
               #"E" : "East",
               #"W" : "West",
               "Blvd" : "Boulevard",
               "Blvd." : "Boulevard"
            }

def fix_street(elem):

    street_types = defaultdict(set)
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if is_street_name(tag):
                audit_street_type(street_types, tag.attrib['v'])

            for st_type, ways in street_types.items():
                for name in ways:
                    for key,value in mapping.items():
                        n = street_type_re.search(name)
                        if n:
                            street_type = n.group()
                            if street_type not in expected:
                                if street_type in mapping:
                                    better_name = name.replace(key,value)
                                    if better_name != name:
                                        print ("Fixed Street:", tag.attrib['v'], "=>", better_name)
                                        tag.attrib['v'] = better_name
                                        return

                                
fix_street(elem)

# %%
def fix_state(elem):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_state(tag):
                    if tag.attrib['v'] != 'MI':
                        print ("Fixed State: ", tag.attrib['v'], "=> 'MI'")
                        tag.attrib['v'] = 'MI'

# %% [markdown]
# # Data Reshaping and Exporting to CSV Files

# %%
# schema.py

schema = {
    'node': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'lat': {'required': True, 'type': 'float', 'coerce': float},
            'lon': {'required': True, 'type': 'float', 'coerce': float},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
            }
        }
    },
    'node_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    },
    'way': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
            }
        }
    },
    'way_nodes': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'node_id': {'required': True, 'type': 'integer', 'coerce': int},
                'position': {'required': True, 'type': 'integer', 'coerce': int}
            }
        }
    },
    'way_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    }
}

# %% [markdown]
# **Preparing the data to be inserted into a SQL database**

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET

import cerberus

import schema

OSM_PATH = "sample.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

print ("Street Names and State Codes Fixed:")
print ("\n")

# Fix Street & State Names                             
def fix_element(elem):
    fix_street(elem)
    fix_state(elem)
                                

def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    # Fix data issues, based on auditing results

    fix_element(element)

    # Shape elements, by splitting the attribute fields per the rules described in the
    # Udacity commentary

    if element.tag == 'node':

            for node_field in node_attr_fields:
                node_attribs[node_field] =element.attrib[node_field]

            for tag in element.iter('tag'):
                k = tag.attrib['k']

                # ignores tags containing problem characters in the k tag attribute:

                if re.search(PROBLEMCHARS,k):
                    continue
                else:
                    pass

                tag_dict = {}

                tag_dict['id'] = node_attribs['id']

                colon_find = re.split('[:]', k)

                if len(colon_find) == 1:

                    tag_dict['key'] = k
                    tag_dict['type'] = 'regular'

                elif len(colon_find) == 2:

                    tag_dict['key'] = colon_find[1]
                    tag_dict['type'] = colon_find[0]

                elif len(colon_find) > 2:

                    tag_dict['key'] = ':'.join(colon_find[1:])
                    tag_dict['type'] = colon_find[0]

                tag_dict['value'] = tag.attrib['v']

                tags.append(tag_dict)

            return {'node': node_attribs, 'node_tags': tags}

    elif element.tag == 'way':

        for way_field in way_attr_fields:
            way_attribs[way_field] =element.attrib[way_field]

        for tag in element.iter('tag'):
            k = tag.attrib['k']

            # ignores tags containing problem characters in the k tag attribute:

            if re.search(PROBLEMCHARS,k):
                print ("Problem character found - skipping element")
                continue
            else:
                pass

            tag_dict = {}

            tag_dict['id'] = way_attribs['id']

            colon_find = re.split('[:]', k)

            if len(colon_find) == 1:

                tag_dict['key'] = k
                tag_dict['type'] = 'regular'

            elif len(colon_find) == 2:

                tag_dict['key'] = colon_find[1]
                tag_dict['type'] = colon_find[0]

            elif len(colon_find) > 2:

                tag_dict['key'] = ':'.join(colon_find[1:])
                tag_dict['type'] = colon_find[0]

            tag_dict['value'] = tag.attrib['v']

            tags.append(tag_dict)

        n = 0
        for nd in element.iter('nd'):

            nd_dict = {}

            nd_dict['id'] = way_attribs['id']
            nd_dict['node_id'] = nd.attrib['ref']
            nd_dict['position'] = n
            way_nodes.append(nd_dict)
            n+=1

        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}


        
# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=schema):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.items())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: v for k, v in row.items()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w', 'utf-8') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w', 'utf-8') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w', 'utf-8') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w', 'utf-8') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w', 'utf-8') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=False)
    
print("Reshaping and export complete.")
# Out:
# Street Names and State Codes Fixed:
#
#
# Fixed Street: E 9 Mile Rd => E 9 Mile Road
# Fixed Street: Gratiot Ave => Gratiot Avenue
# Fixed Street: Grand River Ave => Grand River Avenue
# Fixed Street: E McNichols Rd => E McNichols Road
# Fixed Street: W. 7 Mile Rd. => W. 7 Mile Road.
# Fixed Street: E 11 Mile Rd => E 11 Mile Road
# Fixed Street: Westchester Dr. => Westchester Drive
# Fixed Street: Westchester Dr. => Westchester Drive
# Fixed Street: Little River Blvd. => Little River Boulevard.
# Fixed Street: Little River Blvd. => Little River Boulevard.
# Fixed Street: Evergreen Rd => Evergreen Road
# Fixed Street: East Boston Blvd => East Boston Boulevard
# Fixed Street: Plymouth Rd => Plymouth Road
# Fixed Street: Lacasse Blvd => Lacasse Boulevard
# Fixed Street: East Boston Blvd => East Boston Boulevard
# Fixed Street: West Boston Blvd => West Boston Boulevard
# Fixed Street: Michigan Ave => Michigan Avenue
# Reshaping and export complete.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('data_wrangling_schema.db')
cursor = conn.cursor()
print("Opened database successfully")
# Out:
# Opened database successfully
